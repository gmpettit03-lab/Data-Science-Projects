# %% [markdown]
# 1. The code below produces an error. Fix the error and execute the code using your name. Briefly describe the type of error in a comment inside the cell.

# %%
name=input("Write your name here: ")
print(name)

# %% [markdown]
# 2. Write a program to calculate the area of triangle. Accept input base and height from users and report the area. Create this program in a separate workbook and submit it through the assignment for Lecture 2.

# %%
base= float(input(""))
height= float(input(""))
print("Height =", height,"Base =", base)
AreaTi= (base*height)/2
print("Area Triangle= 1/2*b*h", AreaTi)
