# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import random

# %%
# Set up Selenium
options = Options()
options.add_argument("start-maximized")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64)")
driver = webdriver.Chrome(options=options)

# Visit a Transfermarkt page
url = "https://www.transfermarkt.com/fc-barcelona/kader/verein/131"
driver.get(url)

# Wait for JS to load
time.sleep(random.uniform(3, 6))

# Extract HTML
soup = BeautifulSoup(driver.page_source, "html.parser")

# Parse player names
players = soup.select("table.items td.posrela a.spielprofil_tooltip")
for player in players:
    print(player.text.strip())

driver.quit()

# %%
print(soup)
# Out:
# <html class="sp-message-open" data-previous-scroll-y="-0px" lang="en"><head>
# <script src="https://cp.transfermarkt.com/now.js"></script><script data-description="sourcepoint stub code" type="text/javascript">
# ...

# %%
# Parse player names
players = soup.select("table.items td.posrela a.spielprofil_tooltip")
for player in players:
    print(player.text.strip())

# %%
import pandas as pd

df = pd.DataFrame(players, columns=['Player Name'])
print(df)
# Out:
# Empty DataFrame
# Columns: [Player Name]
# Index: []
