# %%
# Create a cell that accepts the users name as an input and prints "Hello " and their name

# %%
# Write a while loop that adds the number 1-50 (inclusive)

i=0                        # Count where you are in the loop
total=0                    # Hold the running sum

#Construct your while loop here.





print(total)

# %%
#Write a function that reports true if the input is odd and false if the input is even



def odd(i):                          # The function odds takes one input, I call 'i'




print(odd(99))                       # Should return true
print(odd(98))                       # Should return false

# %%
# Write a loop that that prints the conditions from the condition list unless they are equal to rain. 
# Your loop should be flexible enough to work on both lists below

conditions=["snow", "rain", "sun", "clouds"]
#conditions=["rain", "sun", "clouds", "snow"]
