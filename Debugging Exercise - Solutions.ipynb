# %% [markdown]
# # Debugging Practice - SOLUTIONS
# Debug the cells below so that code works as intended. Each cell has a description of the expected behavior. You may use any online resources you think will be helpful. I encourage you to work on each one for at least 5 minutes before asking for help.

# %%
# This code should accept a password and tell the user if the password is correct or incorrect.
passw = input("Enter Password)
if passw == "ABC123":
        print("Accepted")
elif
print("Incorrect Password")

# %%
passw = input("Enter Password")          # Add a quote here
if passw == "ABC123":
        print("Accepted")
else:                                   # Need a colon here
    print("Incorrect Password")         # Tab this over so it's part of the elif statement, just need an else

# %%
# Today's electricity price in Texas is $50 per MWhr. Ask the user to guess the price. 
# Create a variable representing the guess. Tell the user if it's too low, too high or about right. Give them a 5% margin of error 

guess == float.input("What is today's electricity price in Texas?))

if guess <= 47.50
    print ('Too low')
elif guess > 47.50 && guess < 55:
    print ("That's about right")
elif:
    print ("Too high")

# %%
guess = float(input("What is today's electricity price in Texas? "))    # Correct the input function, quotes and add a space

if guess <= 47.50:                                                      # Add a colon
    print ('Too low')
elif guess > 47.50 and guess < 52.50:                                   # Use "and" instead of "&" and correct the upper bound
    print ("That's about right")
else:
    print ("Too high")

# %%
# Create a function that provides a greeting. Call that function  with your name and have the greeting print out
def greet_func(name):
    greeting = 'Hi ' & name
    return greet_func

greeting = greet-func('Scott')

# %%
def greet_func(name):                                
    greeting = 'Hi ' + name                          # Use + not an ampersand
    return greeting                                  # Return the string, not the function

greeting = greet_func('Scott')                       # The function has an underscore, not hyphen
print(greeting)                                      # We have to call the function to get it to run

# %%
# Iterate through a list of numbers and saving the sum. Stop when you get the number 100 from the list and print the sum
# Make sure the program works for both lists

lst1=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66, 76, 12, 35, 13, 100, 80, 95]
lst2=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66]

i = 1
while i < len(lst1):                                                        #len(lst1) returns the lenght of the list. It's correct here.
    if lst1[i] == 100:                                                      #list1[i] calls the ith element of the list. it's correct here.
        print(i)
    i = i+1

# %%
# Iterate through a list of numbers and saving the sum. Stop when you get the number 100 from the list and print the sum
# Make sure the program works for both lists

lst1=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66, 76, 12, 35, 13, 100, 80, 95]
lst2=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66]

i = 0                                                                       # Set counter to 0, not 1
total=0                                                                     # Create a variable to hold the total  
while i < len(lst2):                                                        
    total=total+lst2[i]                                                     # Update the total
    if lst2[i] == 100:                                                     
        break                                                               # Use a break to get out of the while loop
    i=i+1                                                                   # Iterate at the end or it will break the if statement
print(total)                                                                # Print outside the last loop
# Out:
# 564

# %%
# Optional: If you have time, update the cell above to do the same calculations, but to exclude 100 for the sum you save. 
# You still stop when you get to 100, but now 100 is not part of the sum you report. 


lst1=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66, 76, 12, 35, 13, 100, 80, 95]
lst2=[10, 15, 22, 99, 98, 85, 45, 59, 65, 66]

i = 0                                                                      
total=0                                                                    
while i < len(lst2):                                                        
    if lst2[i] == 100:                                                      
        break                                                               
    total=total+lst2[i]                                                     # Move the total to happen after the break
    i=i+1                                                                  
print(total)
